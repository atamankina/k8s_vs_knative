# %% [markdown]
# # Library Imports

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

# %% [markdown]
# # Data Imports

# %%
tests = pd.read_csv('test_cases.csv')
tests
# Out:
#       test  users  hatch_rate               test_set
# 0    test1      1           0         SingleReadSlow
# 1    test2    100          10  ReadMultipleEndpoints
# 2    test3    100          10      MultipleReadWrite
# 3    test4    500          50  ReadMultipleEndpoints
# 4    test5    500          50      MultipleReadWrite
# 5    test6   1000         100  ReadMultipleEndpoints
# 6    test7   1000         100      MultipleReadWrite
# 7    test8    250          25  ReadMultipleEndpoints
# 8    test9    250          25      MultipleReadWrite
# 9   test10    750           5  ReadMultipleEndpoints
# 10  test11    750           5      MultipleReadWrite

# %%
kn_test1 = pd.read_csv('knative_test1_requests.csv')
kn_test1
# Out:
#   Method         Name  # requests  # failures  Median response time  \
# 0    GET  /reviews/10           7           0                 18000
# 1   None        Total           7           0                 18000
#
#    Average response time  Min response time  Max response time  \
# 0                  20747              17431              25342
# 1                  20747              17431              25342
#
#    Average Content Size  Requests/s
# 0                   222         0.0
# 1                   222         0.0

# %%
kn_distr1 = pd.read_csv('knative_test1_distribution.csv')
kn_distr1
# Out:
#               Name  # requests    50%    66%    75%    80%    90%    95%  \
# 0  GET /reviews/10           7  18000  24000  25000  25000  25000  25000
# 1            Total           7  18000  24000  25000  25000  25000  25000
#
#      98%    99%   100%
# 0  25000  25000  25000
# 1  25000  25000  25000

# %%
kn_test2 = pd.read_csv('knative_test2_requests.csv')
kn_test2
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        1175           2
# 1    GET             /reviews/10        1138           3
# 2    GET  /reviews/restaurant/10        1093           3
# 3    GET        /reviews/user/10        1085           3
# 4   None                   Total        4491          11
#
#    Median response time  Average response time  Min response time  \
# 0                  5300                   5682               1618
# 1                  5100                   5349                243
# 2                  5200                   5485               1425
# 3                  5200                   5527                260
# 4                  5200                   5512                243
#
#    Max response time  Average Content Size  Requests/s
# 0              27566                319825        3.93
# 1              27365                   221        3.80
# 2              21840                  3396        3.65
# ...

# %%
kn_distr2 = pd.read_csv('knative_test2_distribution.csv')
kn_distr2
# Out:
#                          Name  # requests   50%   66%   75%   80%   90%   95%  \
# 0               GET /reviews/        1175  5300  5400  5400  5500  5700  7100
# 1             GET /reviews/10        1138  5100  5100  5200  5200  5300  6000
# 2  GET /reviews/restaurant/10        1093  5200  5200  5300  5300  5500  6900
# 3        GET /reviews/user/10        1085  5200  5200  5300  5300  5500  6900
# 4                       Total        4491  5200  5300  5300  5400  5600  6800
#
#      98%    99%   100%
# 0  16000  21000  28000
# 1  12000  19000  27000
# 2  14000  18000  22000
# 3  15000  19000  27000
# 4  15000  19000  28000

# %%
kn_test3 = pd.read_csv('knative_test3_requests.csv')
kn_test3
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/         265           1
# 1   POST               /reviews/        1020           1
# 2    GET             /reviews/10        1264           1
# 3    GET  /reviews/restaurant/10         757           1
# 4    GET        /reviews/user/10         281           1
# 5   None                   Total        3587           5
#
#    Median response time  Average response time  Min response time  \
# 0                  7200                   7676                496
# 1                  7100                   7269               2715
# 2                  6700                   6929                445
# 3                  6800                   7101                638
# 4                  6700                   7007                508
# 5                  6900                   7123                445
#
#    Max response time  Average Content Size  Requests/s
# ...

# %%
kn_distr3 = pd.read_csv('knative_test3_distribution.csv')
kn_distr3
# Out:
#                          Name  # requests   50%   66%   75%   80%   90%   95%  \
# 0               GET /reviews/         265  7200  7500  7600  7700  8000  8200
# 1              POST /reviews/        1020  7100  7300  7400  7500  7600  7800
# 2             GET /reviews/10        1264  6700  6800  6900  7000  7200  7400
# 3  GET /reviews/restaurant/10         757  6800  7000  7100  7100  7300  7500
# 4        GET /reviews/user/10         281  6700  7000  7000  7100  7300  7400
# 5                       Total        3587  6900  7100  7200  7300  7500  7700
#
#      98%    99%   100%
# 0  20000  24000  27000
# 1   9400  16000  27000
# 2  16000  20000  27000
# 3  19000  21000  27000
# 4  13000  24000  25000
# 5  15000  20000  27000

# %%
kn_test4 = pd.read_csv('knative_test4_requests.csv')
kn_test4
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        4525         831
# 1    GET             /reviews/10        4636         879
# 2    GET  /reviews/restaurant/10        4461         813
# 3    GET        /reviews/user/10        4597         808
# 4   None                   Total       18219        3331
#
#    Median response time  Average response time  Min response time  \
# 0                  7600                   7585                229
# 1                  6900                   6693                231
# 2                  7000                   6834                234
# 3                  7000                   6876                229
# 4                  7100                   6995                229
#
#    Max response time  Average Content Size  Requests/s
# 0              29174                261536       15.11
# 1              29900                   179       15.48
# 2              39599                  2785       14.89
# ...

# %%
kn_distr4 = pd.read_csv('knative_test4_distribution.csv')
kn_distr4
# Out:
#                          Name  # requests   50%   66%   75%    80%    90%  \
# 0               GET /reviews/        4525  7600  8900  9700  10000  13000
# 1             GET /reviews/10        4636  6900  8200  8800   9300  11000
# 2  GET /reviews/restaurant/10        4461  7000  8300  8800   9400  11000
# 3        GET /reviews/user/10        4597  7000  8300  8900   9400  11000
# 4                       Total       18219  7100  8400  9000   9500  11000
#
#      95%    98%    99%   100%
# 0  15000  18000  19000  29000
# 1  12000  14000  18000  30000
# 2  12000  15000  18000  40000
# 3  12000  15000  18000  33000
# 4  13000  16000  18000  40000

# %%
kn_test5 = pd.read_csv('knative_test5_requests.csv')
kn_test5
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        1073          90
# 1   POST               /reviews/        4271         341
# 2    GET             /reviews/10        5425         455
# 3    GET  /reviews/restaurant/10        3232         269
# 4    GET        /reviews/user/10        1085          80
# 5   None                   Total       15086        1235
#
#    Median response time  Average response time  Min response time  \
# 0                  9700                   9980                232
# 1                  8400                   8762                226
# 2                  7900                   8279                226
# 3                  7900                   8382                228
# 4                  8300                   8625                233
# 5                  8200                   8584                226
#
#    Max response time  Average Content Size  Requests/s
# ...

# %%
kn_distr5 = pd.read_csv('knative_test5_distribution.csv')
kn_distr5
# Out:
#                          Name  # requests   50%    66%    75%    80%    90%  \
# 0               GET /reviews/        1073  9700  12000  13000  13000  16000
# 1              POST /reviews/        4271  8400  11000  12000  12000  13000
# 2             GET /reviews/10        5425  7900  10000  11000  11000  13000
# 3  GET /reviews/restaurant/10        3232  7900  10000  11000  12000  13000
# 4        GET /reviews/user/10        1085  8300  11000  11000  12000  13000
# 5                       Total       15086  8200  11000  11000  12000  13000
#
#      95%    98%    99%   100%
# 0  18000  27000  32000  40000
# 1  15000  25000  29000  34000
# 2  15000  23000  29000  34000
# 3  15000  25000  29000  34000
# 4  15000  26000  31000  34000
# 5  15000  25000  30000  40000

# %%
kn_test6 = pd.read_csv('knative_test6_requests.csv')
kn_test6
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        8643        6295
# 1    GET             /reviews/10        8728        6441
# 2    GET  /reviews/restaurant/10        8761        6442
# 3    GET        /reviews/user/10        8652        6371
# 4   None                   Total       34784       25549
#
#    Median response time  Average response time  Min response time  \
# 0                  2000                   7822                248
# 1                  1900                   7124                277
# 2                  1900                   7146                237
# 3                  1900                   7047                273
# 4                  1900                   7284                237
#
#    Max response time  Average Content Size  Requests/s
# 0             103076                 87033       28.85
# 1             100063                    58       29.13
# 2              99293                   901       29.24
# ...

# %%
kn_distr6 = pd.read_csv('knative_test6_distribution.csv')
kn_distr6
# Out:
#                          Name  # requests   50%   66%   75%    80%    90%  \
# 0               GET /reviews/        8643  2000  4500  9400  12000  25000
# 1             GET /reviews/10        8728  1900  4400  8500  11000  21000
# 2  GET /reviews/restaurant/10        8761  1900  4300  8900  11000  21000
# 3        GET /reviews/user/10        8652  1900  4300  8100  10000  20000
# 4                       Total       34784  1900  4400  8800  11000  22000
#
#      95%    98%    99%    100%
# 0  36000  46000  57000  103000
# 1  33000  42000  55000  100000
# 2  33000  44000  56000   99000
# 3  32000  45000  58000  104000
# 4  33000  45000  56000  104000

# %%
kn_test7 = pd.read_csv('knative_test7_requests.csv')
kn_test7
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        1927        1107
# 1   POST               /reviews/        8022        4570
# 2    GET             /reviews/10       10047        5747
# 3    GET  /reviews/restaurant/10        6142        3532
# 4    GET        /reviews/user/10        2038        1169
# 5   None                   Total       28176       16125
#
#    Median response time  Average response time  Min response time  \
# 0                  3900                  10404                234
# 1                  3600                   8997                231
# 2                  3400                   8690                233
# 3                  3300                   8614                229
# 4                  3300                   8534                235
# 5                  3500                   8867                229
#
#    Max response time  Average Content Size  Requests/s
# ...

# %%
kn_distr7 = pd.read_csv('knative_test7_distribution.csv')
kn_distr7
# Out:
#                          Name  # requests   50%    66%    75%    80%    90%  \
# 0               GET /reviews/        1927  3900  13000  17000  19000  27000
# 1              POST /reviews/        8022  3600  10000  14000  15000  23000
# 2             GET /reviews/10       10047  3400   9900  13000  15000  22000
# 3  GET /reviews/restaurant/10        6142  3300   9900  13000  15000  22000
# 4        GET /reviews/user/10        2038  3300   9300  13000  15000  22000
# 5                       Total       28176  3500  10000  14000  15000  23000
#
#      95%    98%    99%   100%
# 0  35000  45000  56000  94000
# 1  32000  46000  52000  90000
# 2  31000  45000  56000  88000
# 3  31000  46000  52000  86000
# 4  32000  46000  56000  82000
# 5  32000  46000  53000  94000

# %%
kn_test8 = pd.read_csv('knative_test8_requests.csv')
kn_test8
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        3040         286
# 1    GET             /reviews/10        3127         313
# 2    GET  /reviews/restaurant/10        3077         299
# 3    GET        /reviews/user/10        3084         301
# 4   None                   Total       12328        1199
#
#    Median response time  Average response time  Min response time  \
# 0                  5300                   5162                233
# 1                  4900                   4769                227
# 2                  5100                   4856                227
# 3                  5100                   4880                230
# 4                  5100                   4915                227
#
#    Max response time  Average Content Size  Requests/s
# 0              22716                290230       10.16
# 1              22369                   199       10.45
# 2              22830                  3075       10.29
# ...

# %%
kn_distr8 = pd.read_csv('knative_test8_distribution.csv')
kn_distr8
# Out:
#                          Name  # requests   50%   66%   75%   80%   90%   95%  \
# 0               GET /reviews/        3040  5300  5800  6600  7400  8400  8700
# 1             GET /reviews/10        3127  4900  5400  6000  6700  8100  8300
# 2  GET /reviews/restaurant/10        3077  5100  5500  6000  6800  8200  8400
# 3        GET /reviews/user/10        3084  5100  5500  6000  6900  8200  8400
# 4                       Total       12328  5100  5600  6200  7000  8200  8500
#
#     98%    99%   100%
# 0  9700  12000  23000
# 1  9100  12000  22000
# 2  9200  12000  23000
# 3  9200  11000  18000
# 4  9300  12000  23000

# %%
kn_test9 = pd.read_csv('knative_test9_requests.csv')
kn_test9
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/         710           9
# 1   POST               /reviews/        2877          30
# 2    GET             /reviews/10        3566          30
# 3    GET  /reviews/restaurant/10        2135          27
# 4    GET        /reviews/user/10         746          12
# 5   None                   Total       10034         108
#
#    Median response time  Average response time  Min response time  \
# 0                  6500                   6922                525
# 1                  5800                   6438                238
# 2                  5400                   6088                233
# 3                  5500                   6179                235
# 4                  5500                   6046                244
# 5                  5600                   6264                233
#
#    Max response time  Average Content Size  Requests/s
# ...

# %%
kn_distr9 = pd.read_csv('knative_test9_distribution.csv')
kn_distr9
# Out:
#                          Name  # requests   50%   66%   75%   80%   90%   95%  \
# 0               GET /reviews/         710  6500  7300  7800  8000  8400  9100
# 1              POST /reviews/        2877  5800  6800  7400  7500  7900  8200
# 2             GET /reviews/10        3566  5400  6400  6900  7100  7500  7800
# 3  GET /reviews/restaurant/10        2135  5500  6500  7000  7200  7500  7900
# 4        GET /reviews/user/10         746  5500  6500  6900  7100  7500  7800
# 5                       Total       10034  5600  6600  7100  7300  7700  8100
#
#      98%    99%   100%
# 0  17000  23000  27000
# 1  15000  22000  30000
# 2  17000  23000  32000
# 3  18000  23000  34000
# 4  14000  22000  28000
# 5  17000  23000  34000

# %%
kn_test10 = pd.read_csv('knative_test10_requests.csv')
kn_test10
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        4715        3573
# 1    GET             /reviews/10        5026        3687
# 2    GET  /reviews/restaurant/10        5152        3765
# 3    GET        /reviews/user/10        5064        3619
# 4   None                   Total       19957       14644
#
#    Median response time  Average response time  Min response time  \
# 0                   340                  10216                227
# 1                   350                   5441                226
# 2                   350                   5511                226
# 3                   360                   5889                227
# 4                   350                   6701                226
#
#    Max response time  Average Content Size  Requests/s
# 0              99873                285453       15.75
# 1              36625                    59       16.79
# 2             110877                   916       17.21
# ...

# %%
kn_distr10 = pd.read_csv('knative_test10_distribution.csv')
kn_distr10
# Out:
#                          Name  # requests  50%   66%   75%    80%    90%  \
# 0               GET /reviews/        4715  340   600  7700  21000  44000
# 1             GET /reviews/10        5026  350   810  7700  12000  23000
# 2  GET /reviews/restaurant/10        5152  350   810  7900  12000  23000
# 3        GET /reviews/user/10        5064  360  1000  9300  13000  24000
# 4                       Total       19957  350   760  8200  13000  26000
#
#      95%    98%    99%    100%
# 0  57000  70000  77000  100000
# 1  28000  31000  32000   37000
# 2  28000  31000  33000  111000
# 3  28000  31000  33000   38000
# 4  31000  47000  59000  111000

# %%
kn_test11 = pd.read_csv('knative_test11_requests.csv')
kn_test11
# Out:
#   Method                    Name  # requests  # failures  \
# 0    GET               /reviews/        1913        1118
# 1   POST               /reviews/        7933        4797
# 2    GET             /reviews/10        9989        5962
# 3    GET  /reviews/restaurant/10        5976        3657
# 4    GET        /reviews/user/10        1996        1160
# 5   None                   Total       27807       16694
#
#    Median response time  Average response time  Min response time  \
# 0                   680                   5676                227
# 1                   640                   4908                226
# 2                   670                   4765                225
# 3                   620                   4627                225
# 4                   770                   4757                226
# 5                   660                   4839                225
#
#    Max response time  Average Content Size  Requests/s
# ...

# %%
kn_distr11 = pd.read_csv('knative_test11_distribution.csv')
kn_distr11
# Out:
#                          Name  # requests  50%   66%    75%    80%    90%  \
# 0               GET /reviews/        1913  680  9700  11000  12000  13000
# 1              POST /reviews/        7933  640  7500  11000  11000  12000
# 2             GET /reviews/10        9989  670  6900  10000  11000  12000
# 3  GET /reviews/restaurant/10        5976  620  6000  10000  11000  12000
# 4        GET /reviews/user/10        1996  770  7400  10000  11000  12000
# 5                       Total       27807  660  7000  10000  11000  12000
#
#      95%    98%    99%   100%
# 0  17000  23000  36000  64000
# 1  14000  20000  32000  59000
# 2  13000  20000  33000  60000
# 3  13000  20000  31000  59000
# 4  13000  19000  28000  57000
# 5  13000  21000  32000  64000

# %% [markdown]
# # Gather test totals

# %%
med = 'Median response time'
avg = 'Average response time'
minn = 'Min response time'
maxx = 'Max response time'

med_tuple = kn_test1[med][1], kn_test2[med][4], kn_test3[med][5], kn_test4[med][4], kn_test5[med][5], kn_test6[med][4], kn_test7[med][5]
avg_tuple = kn_test1[avg][1], kn_test2[avg][4], kn_test3[avg][5], kn_test4[avg][4], kn_test5[avg][5], kn_test6[avg][4], kn_test7[avg][5]
maxx_tuple = kn_test1[maxx][1], kn_test2[maxx][4], kn_test3[maxx][5], kn_test4[maxx][4], kn_test5[maxx][5], kn_test6[maxx][4], kn_test7[maxx][5]
minn_tuple = kn_test1[minn][1], kn_test2[minn][4], kn_test3[minn][5], kn_test4[minn][4], kn_test5[minn][5], kn_test6[minn][4], kn_test7[minn][5]

test_list = list(tests['test'][0:7])
med_list = list(med_tuple)
avg_list = list(avg_tuple)
min_list = list(minn_tuple)
max_list = list(maxx_tuple)

# %%
data = {'tests': test_list,
        med: med_list,
        avg: avg_list,
        minn: min_list,
        maxx: max_list}
test_totals = pd.DataFrame(data=data)
test_totals
# Out:
#    tests  Median response time  Average response time  Min response time  \
# 0  test1                 18000                  20747              17431
# 1  test2                  5200                   5512                243
# 2  test3                  6900                   7123                445
# 3  test4                  7100                   6995                229
# 4  test5                  8200                   8584                226
# 5  test6                  1900                   7284                237
# 6  test7                  3500                   8867                229
#
#    Max response time
# 0              25342
# 1              27566
# 2              27135
# 3              39599
# 4              40462
# 5             104044
# 6              94226
